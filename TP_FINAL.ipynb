# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
try: #Trini
  ruta_carpeta = "drive.google.com/file/d/1vrkHO9vKccRya0a4R0iKN5idxbamKTOi/view?usp=drive_link"
  df = pd.read_csv(ruta_carpeta)
except: #Marti
  try:
    ruta_carpeta = "drive/MyDrive/TP IA/dataset_tripadvisor-scraper_2024-06-12_17-49-14-591.csv"
    df = pd.read_csv(ruta_carpeta)
  except: #Clara
    ruta_carpeta = "drive/MyDrive/dataset_tripadvisor-scraper_2024-06-12_17-49-14-591.csv"
    df = pd.read_csv(ruta_carpeta)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 76 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   cuisines/items/0/tag/localizedName             5454 non-null   object
#  1   cuisines/items/1/tag/localizedName             4122 non-null   object
#  2   cuisines/items/2/tag/localizedName             2542 non-null   object
#  3   cuisines/items/3/tag/localizedName             1377 non-null   object
#  4   cuisines/items/4/tag/localizedName             675 non-null    object
#  5   cuisines/items/5/tag/localizedName             312 non-null    object
#  6   cuisines/items/6/tag/localizedName             120 non-null    object
#  7   cuisines/items/7/tag/localizedName             22 non-null     object
#  8   cuisines/items/8/tag/localizedName             5 non-null      object
#  9   cuisines/items/9/tag/localizedName             3 non-null      object
#  10  cuisines/items/10/tag/localizedName            1 non-null      object
#  11  detailPageRoute/url                            6871 non-null   object
#  12  establishmentTypes/items/0/id                  6825 non-null   float64
#  13  establishmentTypes/items/0/tag/localizedName   6825 non-null   object
#  14  establishmentTypes/items/1/id                  392 non-null    float64
#  15  establishmentTypes/items/1/tag/localizedName   392 non-null    object
#  16  establishmentTypes/items/2/id                  30 non-null     float64
#  17  establishmentTypes/items/2/tag/localizedName   30 non-null     object
#  18  establishmentTypes/items/3/id                  2 non-null      float64
#  19  establishmentTypes/items/3/tag/localizedName   2 non-null      object
#  20  isAdsPreview                                   0 non-null      float64
#  21  isLocalChef                                    6871 non-null   bool
#  22  isPremium                                      6871 non-null   bool
#  23  isSponsoredListing                             0 non-null      float64
#  24  location/distance                              0 non-null      float64
#  25  location/geoPoint                              0 non-null      float64
#  26  location/geoPoint/latitude                     6582 non-null   float64
#  27  location/geoPoint/longitude                    6582 non-null   float64
#  28  locationId                                     6871 non-null   int64
#  29  menu/hasProvider                               6871 non-null   bool
#  30  menu/menuUrl                                   996 non-null    object
#  31  name                                           6871 non-null   object
#  32  neighborhoods/0/neighborhood/name              4453 non-null   object
#  33  neighborhoods/1/neighborhood/name              1493 non-null   object
#  34  neighborhoods/2/neighborhood/name              386 non-null    object
#  35  neighborhoods/3/neighborhood/name              70 non-null     object
#  36  offers/hasDelivery                             1047 non-null   object
#  37  offers/hasReservation                          1047 non-null   object
#  38  offers/restaurantSpecialOffer                  0 non-null      float64
#  39  offers/slot1Offer                              0 non-null      float64
#  40  offers/slot1Offer/buttonText                   1047 non-null   object
#  41  offers/slot1Offer/canLockTimeslots             1047 non-null   object
#  42  offers/slot1Offer/canProvideTimeslots          1047 non-null   object
#  43  offers/slot1Offer/logoUrl                      1047 non-null   object
#  44  offers/slot1Offer/offerURL                     1047 non-null   object
#  45  offers/slot1Offer/provider                     1047 non-null   object
#  46  offers/slot1Offer/providerDisplayName          1047 non-null   object
#  47  offers/slot1Offer/providerId                   1047 non-null   float64
#  48  offers/slot1Offer/trackingEvent                1047 non-null   object
#  49  offers/slot2Offer                              0 non-null      float64
#  50  openHours/openStatus                           3180 non-null   object
#  51  openHours/openStatusText                       3180 non-null   object
#  52  priceTypes/items/0/secondaryName               4288 non-null   object
#  53  priceTypes/items/1/secondaryName               0 non-null      float64
#  54  reviewSnippetsV2/reviews/0/review/absoluteUrl  5669 non-null   object
#  55  reviewSnippetsV2/reviews/0/review/url          5669 non-null   object
#  56  reviewSnippetsV2/reviews/0/seoContentType      5669 non-null   object
#  57  reviewSnippetsV2/reviews/0/text                5669 non-null   object
#  58  reviewSnippetsV2/reviews/1/review/absoluteUrl  5097 non-null   object
#  59  reviewSnippetsV2/reviews/1/review/url          5097 non-null   object
#  60  reviewSnippetsV2/reviews/1/seoContentType      5097 non-null   object
#  61  reviewSnippetsV2/reviews/1/text                5097 non-null   object
#  62  reviewSummary/count                            6871 non-null   int64
#  63  reviewSummary/rating                           6871 non-null   float64
#  64  sponsoredListingData                           0 non-null      float64
#  65  storyboardStatus                               6871 non-null   bool
#  66  taLocation                                     0 non-null      float64
#  67  taLocation/bestAwardForActiveYear              0 non-null      float64
#  68  taLocation/bestAwardForActiveYear/awardType    79 non-null     object
#  69  taLocation/bestAwardForActiveYear/year         79 non-null     float64
#  70  taLocation/hierarchy/parentGeoId               6870 non-null   float64
#  71  taLocation/names/parentGeo                     6870 non-null   object
#  72  thumbnail                                      0 non-null      float64
#  73  thumbnail/photo/photoSizeDynamic/maxHeight     5214 non-null   float64
#  74  thumbnail/photo/photoSizeDynamic/maxWidth      5214 non-null   float64
#  75  thumbnail/photo/photoSizeDynamic/urlTemplate   5212 non-null   object
# dtypes: bool(4), float64(24), int64(2), object(46)
# memory usage: 3.8+ MB

# %% [markdown]
# Analizamos todas las columnas para limpiar el df, viendo las que son similares juntas

# %% [markdown]
# Comenzamos con las que dicen "cuisine"
#
# A cuisine is a specific set of cooking traditions and practices, often associated with a specific culture or region. Each cuisine involves food preparation in a particular style, of food and drink of particular types, to produce individually consumed items or distinct meals.

# %%
df[['cuisines/items/0/tag/localizedName',
       'cuisines/items/1/tag/localizedName',
       'cuisines/items/2/tag/localizedName',
       'cuisines/items/3/tag/localizedName',
       'cuisines/items/4/tag/localizedName',
       'cuisines/items/5/tag/localizedName',
       'cuisines/items/6/tag/localizedName',
       'cuisines/items/7/tag/localizedName', 'cuisines/items/8/tag/localizedName',
       'cuisines/items/9/tag/localizedName',
       'cuisines/items/10/tag/localizedName']].head()
# Out:
#   cuisines/items/0/tag/localizedName cuisines/items/1/tag/localizedName  \
# 0                              Grill                        Argentinean
# 1                         Steakhouse                           Barbecue
# 2                         Steakhouse                              Grill
# 3                                Bar                      International
# 4                            Italian                             French
#
#   cuisines/items/2/tag/localizedName cuisines/items/3/tag/localizedName  \
# 0                                NaN                                NaN
# 1                              Grill                        Argentinean
# 2                                NaN                                NaN
# 3                               Deli                       Contemporary
# 4                           European                          Sardinian
#
#   cuisines/items/4/tag/localizedName cuisines/items/5/tag/localizedName  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   cuisines/items/6/tag/localizedName cuisines/items/7/tag/localizedName  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   cuisines/items/8/tag/localizedName cuisines/items/9/tag/localizedName  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   cuisines/items/10/tag/localizedName
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN

# %% [markdown]
# Las de localized name parecen contenter las categorias que se le asignaron al restaurante según la comida que sirven, vamos a agruparlas en una sola.

# %%
columns_to_combine = [
    'cuisines/items/0/tag/localizedName',
    'cuisines/items/1/tag/localizedName',
    'cuisines/items/2/tag/localizedName',
    'cuisines/items/3/tag/localizedName',
    'cuisines/items/4/tag/localizedName',
    'cuisines/items/5/tag/localizedName',
    'cuisines/items/6/tag/localizedName',
    'cuisines/items/7/tag/localizedName','cuisines/items/8/tag/localizedName',
       'cuisines/items/9/tag/localizedName',
       'cuisines/items/10/tag/localizedName'
]

# Combina las columnas en una sola lista, excluyendo los valores NaN
df['cuisines'] = df[columns_to_combine].apply(lambda row: [item for item in row if pd.notna(item)], axis=1)

# Elimina las columnas originales si ya no las necesitas
df.drop(columns=columns_to_combine, inplace=True)

# %%
df[['establishmentTypes/items/0/id',
       'establishmentTypes/items/0/tag/localizedName',
       'establishmentTypes/items/1/id',
       'establishmentTypes/items/1/tag/localizedName',
       'establishmentTypes/items/2/id',
       'establishmentTypes/items/2/tag/localizedName',
       'establishmentTypes/items/3/id',
       'establishmentTypes/items/3/tag/localizedName']].sort_values('establishmentTypes/items/3/tag/localizedName').head()
# Out:
#       establishmentTypes/items/0/id  \
# 203                          9900.0
# 4625                         9900.0
# 0                           10591.0
# 1                           10591.0
# 2                           10591.0
#
#      establishmentTypes/items/0/tag/localizedName  \
# 203                                  Coffee & Tea
# 4625                                 Coffee & Tea
# 0                                     Restaurants
# 1                                     Restaurants
# 2                                     Restaurants
#
#       establishmentTypes/items/1/id  \
# 203                          9901.0
# 4625                         9901.0
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#      establishmentTypes/items/1/tag/localizedName  \
# 203                                      Bakeries
# 4625                                     Bakeries
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#       establishmentTypes/items/2/id  \
# 203                          9909.0
# 4625                        16548.0
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#      establishmentTypes/items/2/tag/localizedName  \
# 203                                       Dessert
# 4625                        Specialty Food Market
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#       establishmentTypes/items/3/id  \
# 203                         16556.0
# 4625                        16556.0
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#      establishmentTypes/items/3/tag/localizedName
# 203                                   Quick Bites
# 4625                                  Quick Bites
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN

# %% [markdown]
# Las columnas de establishmentTypes y sus respectivos ids indica qué tipo de lugar. Las de ids las borramos y las otras las unificamos.

# %%
df.drop(columns=['establishmentTypes/items/0/id',
       'establishmentTypes/items/1/id',
       'establishmentTypes/items/2/id',
       'establishmentTypes/items/3/id'], inplace=True)

# %%
columns_to_combine = [
       'establishmentTypes/items/0/tag/localizedName',
       'establishmentTypes/items/1/tag/localizedName',
       'establishmentTypes/items/2/tag/localizedName',
       'establishmentTypes/items/3/tag/localizedName'
]

# Combina las columnas en una sola lista, excluyendo los valores NaN
df['establishmentTypes'] = df[columns_to_combine].apply(lambda row: [item for item in row if pd.notna(item)], axis=1)

# Elimina las columnas originales si ya no las necesitas
df.drop(columns=columns_to_combine, inplace=True)

# %% [markdown]
# Vamos con las siguientes por más de que no tengan tanta relación

# %%
df[['name', 'detailPageRoute/url', 'isAdsPreview', 'isLocalChef', 'isPremium',
       'isSponsoredListing', 'location/distance', 'location/geoPoint',
       'location/geoPoint/latitude', 'location/geoPoint/longitude',
       'locationId', 'menu/hasProvider', 'menu/menuUrl']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         6871 non-null   object
#  1   detailPageRoute/url          6871 non-null   object
#  2   isAdsPreview                 0 non-null      float64
#  3   isLocalChef                  6871 non-null   bool
#  4   isPremium                    6871 non-null   bool
#  5   isSponsoredListing           0 non-null      float64
#  6   location/distance            0 non-null      float64
#  7   location/geoPoint            0 non-null      float64
#  8   location/geoPoint/latitude   6582 non-null   float64
#  9   location/geoPoint/longitude  6582 non-null   float64
#  10  locationId                   6871 non-null   int64
#  11  menu/hasProvider             6871 non-null   bool
#  12  menu/menuUrl                 996 non-null    object
# dtypes: bool(3), float64(6), int64(1), object(3)
# memory usage: 557.1+ KB

# %%
df[['name', 'detailPageRoute/url', 'isAdsPreview', 'isLocalChef', 'isPremium',
       'isSponsoredListing', 'location/distance', 'location/geoPoint',
       'location/geoPoint/latitude', 'location/geoPoint/longitude',
       'locationId', 'menu/hasProvider', 'menu/menuUrl']].head()
# Out:
#                      name                                detailPageRoute/url  \
# 0  Criolla Cooking & Wine  /Restaurant_Review-g312741-d26322909-Reviews-C...
# 1             Fogón Asado  /Restaurant_Review-g312741-d15325004-Reviews-F...
# 2    Argentine Experience  /Restaurant_Review-g312741-d8696562-Reviews-Ar...
# 3   Frenessí Buenos Aires  /Restaurant_Review-g312741-d25279370-Reviews-F...
# 4                Italpast  /Restaurant_Review-g312741-d25198242-Reviews-I...
#
#    isAdsPreview  isLocalChef  isPremium  isSponsoredListing  \
# 0           NaN        False      False                 NaN
# 1           NaN        False       True                 NaN
# 2           NaN        False       True                 NaN
# 3           NaN        False      False                 NaN
# 4           NaN        False      False                 NaN
#
#    location/distance  location/geoPoint  location/geoPoint/latitude  \
# 0                NaN                NaN                  -34.590515
# 1                NaN                NaN                  -34.588530
# 2                NaN                NaN                  -34.580692
# 3                NaN                NaN                  -34.620380
# 4                NaN                NaN                  -34.614132
#
#    location/geoPoint/longitude  locationId  menu/hasProvider  \
# 0                   -58.429607    26322909             False
# 1                   -58.433600    15325004             False
# 2                   -58.432507     8696562             False
# 3                   -58.361164    25279370             False
# 4                   -58.362125    25198242             False
#
#                 menu/menuUrl
# 0                        NaN
# 1  http://www.fogonasado.com
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %% [markdown]
# Vamos a eliminar  isAdsPreview, isSponsoredListing, location/distance, location/geoPoint, locationId y menu/menuUrl que no nos van a servir y/o están vacías.

# %%
df.drop(columns=[ "isAdsPreview", "isSponsoredListing", 'location/distance', 'location/geoPoint' ,"menu/menuUrl", "locationId"], inplace=True)

# %%
df[[ 'neighborhoods/0/neighborhood/name',
       'neighborhoods/1/neighborhood/name',
       'neighborhoods/2/neighborhood/name',
       'neighborhoods/3/neighborhood/name']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   neighborhoods/0/neighborhood/name  4453 non-null   object
#  1   neighborhoods/1/neighborhood/name  1493 non-null   object
#  2   neighborhoods/2/neighborhood/name  386 non-null    object
#  3   neighborhoods/3/neighborhood/name  70 non-null     object
# dtypes: object(4)
# memory usage: 214.8+ KB

# %% [markdown]
# Unificamos todos los barrios

# %%
df[[ 'neighborhoods/0/neighborhood/name',
       'neighborhoods/1/neighborhood/name',
       'neighborhoods/2/neighborhood/name',
       'neighborhoods/3/neighborhood/name']].sort_values('neighborhoods/2/neighborhood/name').head()
# Out:
#      neighborhoods/0/neighborhood/name neighborhoods/1/neighborhood/name  \
# 1472              El Centro (Downtown)                  Theater District
# 2165                            Retiro                       Microcentro
# 2861                       San Nicolás                       Microcentro
# 2841                       San Nicolás                       Microcentro
# 2839                       San Nicolás                       Microcentro
#
#      neighborhoods/2/neighborhood/name neighborhoods/3/neighborhood/name
# 1472                         Balvanera                               NaN
# 2165              El Centro (Downtown)                               NaN
# 2861              El Centro (Downtown)                               NaN
# 2841              El Centro (Downtown)                               NaN
# 2839              El Centro (Downtown)                               NaN

# %%
columns_to_combine = ['neighborhoods/0/neighborhood/name',
       'neighborhoods/1/neighborhood/name',
       'neighborhoods/2/neighborhood/name',
       'neighborhoods/3/neighborhood/name']

# Combina las columnas en una sola lista, excluyendo los valores NaN
df['neighborhoods'] = df[columns_to_combine].apply(lambda row: [item for item in row if pd.notna(item)], axis=1)

# Elimina las columnas originales si ya no las necesitas
df.drop(columns=columns_to_combine, inplace=True)

# %%
df[['offers/hasDelivery',
       'offers/hasReservation', 'offers/restaurantSpecialOffer',
       'offers/slot1Offer', 'offers/slot1Offer/buttonText',
       'offers/slot1Offer/canLockTimeslots',
       'offers/slot1Offer/canProvideTimeslots', 'offers/slot1Offer/logoUrl',
       'offers/slot1Offer/offerURL', 'offers/slot1Offer/provider',
       'offers/slot1Offer/providerDisplayName', 'offers/slot1Offer/providerId',
       'offers/slot1Offer/trackingEvent', 'offers/slot2Offer']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   offers/hasDelivery                     1047 non-null   object
#  1   offers/hasReservation                  1047 non-null   object
#  2   offers/restaurantSpecialOffer          0 non-null      float64
#  3   offers/slot1Offer                      0 non-null      float64
#  4   offers/slot1Offer/buttonText           1047 non-null   object
#  5   offers/slot1Offer/canLockTimeslots     1047 non-null   object
#  6   offers/slot1Offer/canProvideTimeslots  1047 non-null   object
#  7   offers/slot1Offer/logoUrl              1047 non-null   object
#  8   offers/slot1Offer/offerURL             1047 non-null   object
#  9   offers/slot1Offer/provider             1047 non-null   object
#  10  offers/slot1Offer/providerDisplayName  1047 non-null   object
#  11  offers/slot1Offer/providerId           1047 non-null   float64
#  12  offers/slot1Offer/trackingEvent        1047 non-null   object
#  13  offers/slot2Offer                      0 non-null      float64
# dtypes: float64(4), object(10)
# memory usage: 751.6+ KB

# %%
df.drop(columns=["offers/restaurantSpecialOffer", "offers/slot1Offer", "offers/slot2Offer"], inplace=True)

# %%
df[['offers/hasDelivery',
       'offers/hasReservation', 'offers/slot1Offer/buttonText',
       'offers/slot1Offer/canLockTimeslots',
       'offers/slot1Offer/canProvideTimeslots', 'offers/slot1Offer/logoUrl',
       'offers/slot1Offer/offerURL', 'offers/slot1Offer/provider',
       'offers/slot1Offer/providerDisplayName', 'offers/slot1Offer/providerId',
       'offers/slot1Offer/trackingEvent']]
# Out:
#      offers/hasDelivery offers/hasReservation offers/slot1Offer/buttonText  \
# 0                   NaN                   NaN                          NaN
# 1                   NaN                   NaN                          NaN
# 2                   NaN                   NaN                          NaN
# 3                   NaN                   NaN                          NaN
# 4                   NaN                   NaN                          NaN
# ...                 ...                   ...                          ...
# 6866                NaN                   NaN                          NaN
# 6867                NaN                   NaN                          NaN
# 6868                NaN                   NaN                          NaN
# 6869               True                 False                 Order online
# 6870                NaN                   NaN                          NaN
#
#      offers/slot1Offer/canLockTimeslots offers/slot1Offer/canProvideTimeslots  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ...                                 ...                                   ...
# 6866                                NaN                                   NaN
# 6867                                NaN                                   NaN
# 6868                                NaN                                   NaN
# 6869                              False                                 False
# 6870                                NaN                                   NaN
#
#                        offers/slot1Offer/logoUrl  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 6866                                         NaN
# 6867                                         NaN
# 6868                                         NaN
# 6869  /img2/branding/hotels/rappi_04.29.2022.png
# 6870                                         NaN
#
#                              offers/slot1Offer/offerURL  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6866                                                NaN
# 6867                                                NaN
# 6868                                                NaN
# 6869  Y2RuXy9Db21tZXJjZT9wPURlbGl2ZXJ5X1JhcHBpJnNyYz...
# 6870                                                NaN
#
#      offers/slot1Offer/provider offers/slot1Offer/providerDisplayName  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
# ...                         ...                                   ...
# 6866                        NaN                                   NaN
# 6867                        NaN                                   NaN
# 6868                        NaN                                   NaN
# 6869             Delivery_Rappi                                 Rappi
# 6870                        NaN                                   NaN
#
#       offers/slot1Offer/providerId offers/slot1Offer/trackingEvent
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 6866                           NaN                             NaN
# 6867                           NaN                             NaN
# 6868                           NaN                             NaN
# 6869                       15955.0              order_online_click
# 6870                           NaN                             NaN
#
# [6871 rows x 11 columns]

# %%
offer_columns = ['offers/hasDelivery',
       'offers/hasReservation', 'offers/slot1Offer/buttonText',
       'offers/slot1Offer/canLockTimeslots',
       'offers/slot1Offer/canProvideTimeslots', 'offers/slot1Offer/logoUrl',
       'offers/slot1Offer/offerURL', 'offers/slot1Offer/provider',
       'offers/slot1Offer/providerDisplayName', 'offers/slot1Offer/providerId',
       'offers/slot1Offer/trackingEvent']

for col in offer_columns:
  print(col)
  print(df[col].unique())
# Out:
# offers/hasDelivery
# [nan True False]
# offers/hasReservation
# [nan False True]
# offers/slot1Offer/buttonText
# [nan 'Order online' 'Reserve']
# offers/slot1Offer/canLockTimeslots
# [nan False True]
# offers/slot1Offer/canProvideTimeslots
# [nan False True]
# offers/slot1Offer/logoUrl
# [nan '/img2/branding/hotels/rappi_04.29.2022.png'
#  '/img2/branding/hotels/OT_Logo_1000x232.png']
# offers/slot1Offer/offerURL
# [nan
#  '...'
#  '...'
#  ...
#  '...'
#  '...'
#  '...']
# offers/slot1Offer/provider
# [nan 'Delivery_Rappi' 'OpenTable']
# offers/slot1Offer/providerDisplayName
# [nan 'Rappi' 'OpenTable']
# offers/slot1Offer/providerId
# [   nan 15955. 15910.]
# offers/slot1Offer/trackingEvent
# [nan 'order_online_click' 'reserve_click']

# %% [markdown]
# Creo que solo sería interesante la columna de hasDelivery. Qué delivery o las otras columnas no parecen interesantes.

# %%
df.drop(columns=['offers/hasReservation', 'offers/slot1Offer/buttonText',
       'offers/slot1Offer/canLockTimeslots',
       'offers/slot1Offer/canProvideTimeslots', 'offers/slot1Offer/logoUrl',
       'offers/slot1Offer/offerURL', 'offers/slot1Offer/provider',
       'offers/slot1Offer/providerDisplayName', 'offers/slot1Offer/providerId',
       'offers/slot1Offer/trackingEvent'], inplace=True)

# %%
df[['openHours/openStatus', 'openHours/openStatusText',
       'priceTypes/items/0/secondaryName', 'priceTypes/items/1/secondaryName']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   openHours/openStatus              3180 non-null   object
#  1   openHours/openStatusText          3180 non-null   object
#  2   priceTypes/items/0/secondaryName  4288 non-null   object
#  3   priceTypes/items/1/secondaryName  0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 214.8+ KB

# %%
df[['openHours/openStatus', 'openHours/openStatusText',
       'priceTypes/items/0/secondaryName', 'priceTypes/items/1/secondaryName']]
# Out:
#      openHours/openStatus openHours/openStatusText  \
# 0                    OPEN                 Open Now
# 1                    OPEN                 Open Now
# 2                  CLOSED               Closed Now
# 3                    OPEN                 Open Now
# 4                    OPEN                 Open Now
# ...                   ...                      ...
# 6866                  NaN                      NaN
# 6867                 OPEN                 Open Now
# 6868                  NaN                      NaN
# 6869                  NaN                      NaN
# 6870                  NaN                      NaN
#
#      priceTypes/items/0/secondaryName  priceTypes/items/1/secondaryName
# 0                            $$ - $$$                               NaN
# 1                                $$$$                               NaN
# 2                                $$$$                               NaN
# 3                                $$$$                               NaN
# 4                                $$$$                               NaN
# ...                               ...                               ...
# 6866                              NaN                               NaN
# 6867                              NaN                               NaN
# 6868                              NaN                               NaN
# 6869                              NaN                               NaN
# 6870                                $                               NaN
#
# [6871 rows x 4 columns]

# %% [markdown]
# Solo nos interesa la primera de price types.

# %%
df.drop(columns=['openHours/openStatus', 'openHours/openStatusText',
       'priceTypes/items/0/secondaryName', 'priceTypes/items/1/secondaryName'], inplace=True)

# %%
df[['reviewSnippetsV2/reviews/0/review/absoluteUrl',
       'reviewSnippetsV2/reviews/0/review/url',
       'reviewSnippetsV2/reviews/0/seoContentType',
       'reviewSnippetsV2/reviews/0/text',
       'reviewSnippetsV2/reviews/1/review/absoluteUrl',
       'reviewSnippetsV2/reviews/1/review/url',
       'reviewSnippetsV2/reviews/1/seoContentType',
       'reviewSnippetsV2/reviews/1/text', 'reviewSummary/count',
       'reviewSummary/rating']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   reviewSnippetsV2/reviews/0/review/absoluteUrl  5669 non-null   object
#  1   reviewSnippetsV2/reviews/0/review/url          5669 non-null   object
#  2   reviewSnippetsV2/reviews/0/seoContentType      5669 non-null   object
#  3   reviewSnippetsV2/reviews/0/text                5669 non-null   object
#  4   reviewSnippetsV2/reviews/1/review/absoluteUrl  5097 non-null   object
#  5   reviewSnippetsV2/reviews/1/review/url          5097 non-null   object
#  6   reviewSnippetsV2/reviews/1/seoContentType      5097 non-null   object
#  7   reviewSnippetsV2/reviews/1/text                5097 non-null   object
#  8   reviewSummary/count                            6871 non-null   int64
#  9   reviewSummary/rating                           6871 non-null   float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 536.9+ KB

# %%
df[['reviewSnippetsV2/reviews/0/review/absoluteUrl',
       'reviewSnippetsV2/reviews/0/review/url',
       'reviewSnippetsV2/reviews/0/seoContentType',
       'reviewSnippetsV2/reviews/0/text',
       'reviewSnippetsV2/reviews/1/review/absoluteUrl',
       'reviewSnippetsV2/reviews/1/review/url',
       'reviewSnippetsV2/reviews/1/seoContentType',
       'reviewSnippetsV2/reviews/1/text', 'reviewSummary/count',
       'reviewSummary/rating']].head()
# Out:
#        reviewSnippetsV2/reviews/0/review/absoluteUrl  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g3...
# 1  https://www.tripadvisor.com/ShowUserReviews-g3...
# 2  https://www.tripadvisor.com/ShowUserReviews-g3...
# 3  https://www.tripadvisor.com/ShowUserReviews-g3...
# 4  https://www.tripadvisor.com/ShowUserReviews-g3...
#
#                reviewSnippetsV2/reviews/0/review/url  \
# 0  /ShowUserReviews-g312741-d26322909-r954738892-...
# 1  /ShowUserReviews-g312741-d15325004-r781242859-...
# 2  /ShowUserReviews-g312741-d8696562-r784821430-A...
# 3  /ShowUserReviews-g312741-d25279370-r951545216-...
# 4  /ShowUserReviews-g312741-d25198242-r925546414-...
#
#   reviewSnippetsV2/reviews/0/seoContentType  \
# 0                            REVIEW_SNIPPET
# 1                            REVIEW_SNIPPET
# 2                            REVIEW_SNIPPET
# 3                            REVIEW_SNIPPET
# 4                            REVIEW_SNIPPET
#
#                      reviewSnippetsV2/reviews/0/text  \
# 0      Amazing, highly recommend this experience!!!!
# 1  I took my wife and two grown up children for d...
# 2  We found the Argentine Experience to be exactl...
# 3                    Experiencia Inmersiva Excelente
# 4  My husband had the cantelonni stuffed with ￹la...
#
#        reviewSnippetsV2/reviews/1/review/absoluteUrl  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g3...
# 1  https://www.tripadvisor.com/ShowUserReviews-g3...
# 2  https://www.tripadvisor.com/ShowUserReviews-g3...
# 3  https://www.tripadvisor.com/ShowUserReviews-g3...
# 4  https://www.tripadvisor.com/ShowUserReviews-g3...
#
#                reviewSnippetsV2/reviews/1/review/url  \
# 0  /ShowUserReviews-g312741-d26322909-r954717182-...
# 1  /ShowUserReviews-g312741-d15325004-r954738305-...
# 2  /ShowUserReviews-g312741-d8696562-r920224881-A...
# 3  /ShowUserReviews-g312741-d25279370-r942964787-...
# 4  /ShowUserReviews-g312741-d25198242-r922975165-...
#
#   reviewSnippetsV2/reviews/1/seoContentType  \
# 0                            REVIEW_SNIPPET
# 1                            REVIEW_SNIPPET
# 2                            REVIEW_SNIPPET
# 3                            REVIEW_SNIPPET
# 4                            REVIEW_SNIPPET
#
#                reviewSnippetsV2/reviews/1/text  reviewSummary/count  \
# 0                       Cooking with Johnathon                  206
# 1                             A great evening.                 1788
# 2  The ￹steak￻ was beyond delicious and the...                 3063
# 3                  Amazing place great service                  127
# 4             Great food and ￹nice￻ food place                  808
#
#    reviewSummary/rating
# 0                   5.0
# 1                   5.0
# 2                   5.0
# 3                   5.0
# 4                   5.0

# %% [markdown]
# Vamos a reservar las reviews, el count y el rating

# %%
df.drop(columns= ['reviewSnippetsV2/reviews/0/review/absoluteUrl',
       'reviewSnippetsV2/reviews/0/review/url',
       'reviewSnippetsV2/reviews/0/seoContentType',
       'reviewSnippetsV2/reviews/1/review/absoluteUrl',
       'reviewSnippetsV2/reviews/1/review/url',
       'reviewSnippetsV2/reviews/1/seoContentType'], inplace=True)

# %%
df.drop(columns= ['sponsoredListingData', 'taLocation', 'taLocation/bestAwardForActiveYear',"thumbnail"], inplace=True)

# %%
df[[   'storyboardStatus',
       'taLocation/bestAwardForActiveYear/awardType',
       'taLocation/bestAwardForActiveYear/year',
       'taLocation/hierarchy/parentGeoId', 'taLocation/names/parentGeo', 'thumbnail/photo/photoSizeDynamic/maxHeight',
       'thumbnail/photo/photoSizeDynamic/maxWidth',
       'thumbnail/photo/photoSizeDynamic/urlTemplate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   storyboardStatus                              6871 non-null   bool
#  1   taLocation/bestAwardForActiveYear/awardType   79 non-null     object
#  2   taLocation/bestAwardForActiveYear/year        79 non-null     float64
#  3   taLocation/hierarchy/parentGeoId              6870 non-null   float64
#  4   taLocation/names/parentGeo                    6870 non-null   object
#  5   thumbnail/photo/photoSizeDynamic/maxHeight    5214 non-null   float64
#  6   thumbnail/photo/photoSizeDynamic/maxWidth     5214 non-null   float64
#  7   thumbnail/photo/photoSizeDynamic/urlTemplate  5212 non-null   object
# dtypes: bool(1), float64(4), object(3)
# memory usage: 382.6+ KB

# %%
df[[   'storyboardStatus',
       'taLocation/bestAwardForActiveYear/awardType',
       'taLocation/bestAwardForActiveYear/year',
       'taLocation/hierarchy/parentGeoId', 'taLocation/names/parentGeo', 'thumbnail/photo/photoSizeDynamic/maxHeight',
       'thumbnail/photo/photoSizeDynamic/maxWidth',
       'thumbnail/photo/photoSizeDynamic/urlTemplate']]
# Out:
#       storyboardStatus taLocation/bestAwardForActiveYear/awardType  \
# 0                False                                         NaN
# 1                 True                                        BOTB
# 2                 True                                         COE
# 3                False                                         NaN
# 4                False                                         NaN
# ...                ...                                         ...
# 6866             False                                         NaN
# 6867             False                                         NaN
# 6868             False                                         NaN
# 6869             False                                         NaN
# 6870             False                                         NaN
#
#       taLocation/bestAwardForActiveYear/year  \
# 0                                        NaN
# 1                                     2023.0
# 2                                     2023.0
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 6866                                     NaN
# 6867                                     NaN
# 6868                                     NaN
# 6869                                     NaN
# 6870                                     NaN
#
#       taLocation/hierarchy/parentGeoId taLocation/names/parentGeo  \
# 0                             312741.0               Buenos Aires
# 1                             312741.0               Buenos Aires
# 2                             312741.0               Buenos Aires
# 3                             312741.0               Buenos Aires
# 4                             312741.0               Buenos Aires
# ...                                ...                        ...
# 6866                          312741.0               Buenos Aires
# 6867                          312741.0               Buenos Aires
# 6868                          312741.0               Buenos Aires
# 6869                          312741.0               Buenos Aires
# 6870                         2008841.0                 Avellaneda
#
#       thumbnail/photo/photoSizeDynamic/maxHeight  \
# 0                                         3333.0
# 1                                         2268.0
# 2                                         1800.0
# 3                                         1724.0
# 4                                         1057.0
# ...                                          ...
# 6866                                         NaN
# 6867                                         NaN
# 6868                                       521.0
# 6869                                         NaN
# 6870                                      1536.0
#
#       thumbnail/photo/photoSizeDynamic/maxWidth  \
# 0                                        5000.0
# 1                                        3402.0
# 2                                        2700.0
# 3                                        2584.0
# 4                                        1200.0
# ...                                         ...
# 6866                                        NaN
# 6867                                        NaN
# 6868                                      800.0
# 6869                                        NaN
# 6870                                     2560.0
#
#            thumbnail/photo/photoSizeDynamic/urlTemplate
# 0     https://dynamic-media-cdn.tripadvisor.com/medi...
# 1     https://dynamic-media-cdn.tripadvisor.com/medi...
# 2     https://dynamic-media-cdn.tripadvisor.com/medi...
# 3     https://dynamic-media-cdn.tripadvisor.com/medi...
# 4     https://dynamic-media-cdn.tripadvisor.com/medi...
# ...                                                 ...
# 6866                                                NaN
# 6867                                                NaN
# 6868  https://dynamic-media-cdn.tripadvisor.com/medi...
# 6869                                                NaN
# 6870  https://dynamic-media-cdn.tripadvisor.com/medi...
#
# [6871 rows x 8 columns]

# %% [markdown]
# El año en el que se ganó un premio no parece relevanta, quizás el premio si ya que indica el rpestigio de un restaurante.
#
# parentGeoId la eliminamos y todo lo que tenga que ver con la miniatura

# %%
df.drop(columns= ['taLocation/bestAwardForActiveYear/year', 'taLocation/hierarchy/parentGeoId', 'thumbnail/photo/photoSizeDynamic/maxHeight',
       'thumbnail/photo/photoSizeDynamic/maxWidth',
       'thumbnail/photo/photoSizeDynamic/urlTemplate'], inplace=True)

# %% [markdown]
# Finalmente nos quedan 18 columnas

# %% [markdown]
# Que es storyboardStatus y taLocation/names/parentGeo?

# %%
df.columns
# Out:
# Index(['detailPageRoute/url', 'isLocalChef', 'isPremium',
#        'location/geoPoint/latitude', 'location/geoPoint/longitude',
#        'menu/hasProvider', 'name', 'offers/hasDelivery',
#        'reviewSnippetsV2/reviews/0/text', 'reviewSnippetsV2/reviews/1/text',
#        'reviewSummary/count', 'reviewSummary/rating', 'storyboardStatus',
#        'taLocation/bestAwardForActiveYear/awardType',
#        'taLocation/names/parentGeo', 'cuisines', 'establishmentTypes',
#        'neighborhoods'],
#       dtype='object')

# %%
# Renombrar las columnas
df.rename(columns={
    'detailPageRoute/url': 'url',
    'isLocalChef': 'local_chef',
    'isPremium': 'premium',
    'location/geoPoint/latitude': 'latitude',
    'location/geoPoint/longitude': 'longitude',
    'menu/hasProvider': 'menu_provider',
    'name': 'name',
    'offers/hasDelivery': 'has_delivery',
    'reviewSnippetsV2/reviews/0/text': 'review_0',
    'reviewSnippetsV2/reviews/1/text': 'review_1',
    'reviewSummary/count': 'review_count',
    'reviewSummary/rating': 'rating',
    'storyboardStatus': 'storyboard_status',
    'taLocation/bestAwardForActiveYear/awardType': 'award_type',
    'taLocation/names/parentGeo': 'parent_geo',
    'cuisines': 'cuisines',
    'establishmentTypes': 'establishment_types'
}, inplace=True)

# %% [markdown]
# La columns storyboard_status es True cuando tiene un video de presentación en TripAdvisor, no nos brinda información adicional del restaurante.

# %%
df.drop("storyboard_status", inplace=True, axis=1)

# %% [markdown]
# Parent Geo parece ser la localidad

# %%
df.parent_geo.value_counts()
# Out:
# parent_geo
# Buenos Aires      5928
# Avellaneda         107
# Martinez            95
# Vicente Lopez       94
# Lanus               75
#                   ...
# Santa Teresita       1
# Villa Regina         1
# Ayacucho             1
# Espartillar          1
# Longchamps           1
# Name: count, Length: 128, dtype: int64

# %% [markdown]
# Me concentraría solo en Buenos Aires

# %% [markdown]
# *    cambiar columna de rating
# *   vizualicion
# *   NLP  en reviews

# %%
from collections import Counter

# Expande las listas y cuenta cada tipo de cocina
all_cuisines = [cuisine for sublist in df['cuisines'] for cuisine in sublist]
cuisine_counts = Counter(all_cuisines)

# Convierte el resultado a un DataFrame para una mejor visualización
cuisine_counts_df = pd.DataFrame(cuisine_counts.items(), columns=['Cuisine', 'Count'])

# Ordena el DataFrame por el conteo en orden descendente
cuisine_counts_df = cuisine_counts_df.sort_values(by='Count', ascending=False)

# %%
cuisine_counts_df
